# %% [markdown]
# Here is a snippet of the dataframe of Colorado and Utah aggregated demographic, migration and real estate data before and after data cleaning, transformations and improvements in quality

# %% [markdown]
# # Before
# Notice the negative values

# %% [markdown]
# ![before_data.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# # After
# Notice that the negatives values have been removed

# %% [markdown]
# ![after_data.JPG](data:image/jpeg;base64,...)
